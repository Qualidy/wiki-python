# %%
# Aufgabe 1

# {'h': 1, 4: 2, 2.0: "e"} -> {'h': 1}
# {} -> {}
# {5: 1, 4: 2, 2.0: "e"}) -> {}


dict_1 = {'h': 1, 4: 2, 2.0: "e"}
dict_neu = {}


def remove_float_and_int_keys(dic):
    for i in dic:
        if type(i[0]) != int or type(i[0]) != float:
            dict_neu.pop(i)
    return dict_neu


remove_float_and_int_keys(dict_1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 19
#      15             dict_neu.pop(i)
#      16     return dict_neu
# ---> 19 remove_float_and_int_keys(dict_1)
#
# Cell In[1], line 15, in remove_float_and_int_keys(dic)
#      13 for i in dic:
#      14     if type(i[0]) != int or type(i[0]) != float:
# ---> 15         dict_neu.pop(i)
#      16 return dict_neu
#
# KeyError: 'h'

# %%
# 7 Punkte
# Erstelle eine Funktion, die einen String erwartet. Dieser
# String besteht nur aus Groß- und Kleinbuchstaben und einzelnen
# Leerzeichen, die weder am Anfang noch am Ende des Strings sind.
# Schreibe eine Funktion, welche die Reihenfolge alle Buchstaben zwischen
# zwei Leerzeichen ändert.
#
string_2 = "Hallo wie geht es dir" 
# -> "ollaH eiw theg se rid"
# "" -> ""
# "abc" -> "cba"
# "t st s" -> "t ts s"

def resort_within_word(words):
    liste_1 = []
    neu = words.split()
    for i in neu:
        liste_1.append(i[::-1])
    ergebnis = ' '.join(liste_1)
    return ergebnis

resort_within_word(string_2)
# Out:
# 'ollaH eiw theg se rid'

# %%
# Spielwiese Aufgabe 2

neu = string_2.split()

print(neu)

print(neu[0][::-1])

liste_1 = []

for i in neu:
    liste_1.append(i[::-1])

ergebnis = ' '.join(liste_1)
print(ergebnis)
# Out:
# ['Hallo', 'wie', 'geht', 'es', 'dir']
# ollaH
# ollaH eiw theg se rid

# %%
# 7 Punkte
# Schreibe eine Funktion, die eine Liste als Parameter
# annimmt und eine neue Liste zurückgibt, bei der
# alle Elemente außer den größten und dem kleinsten
# entfernt wurden. Wenn die Liste leer ist, soll auch die
# leere Liste zurückgegeben werden.
#
liste_3 = [1,4,3,4,1,2] 
#-> [1,4,4,1]
# [1] -> [1]
# [] -> []
def keep_smallest_biggest(my_list):
    klein = my_list[0]
    groß = my_list[0]
    for i in my_list:
        if i >= max(groß):
            groß.append(i)
        elif i <= min(klein):
            klein.append(i)
    ergebnis = groß + klein
    print(ergebnis)
    


keep_smallest_biggest(liste_3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 25
#      20     ergebnis = groß + klein
#      21     print(ergebnis)
# ---> 25 keep_smallest_biggest(liste_3)
#
# Cell In[4], line 16, in keep_smallest_biggest(my_list)
#      14 groß = my_list[0]
#      15 for i in my_list:
# ---> 16     if i >= max(groß):
#      17         groß.append(i)
#      18     elif i <= min(klein):
#
# TypeError: 'int' object is not iterable

# %%
# Spielwiese Aufgabe 3

max(liste_3)
min(liste_3)

versuch = []
versuch.append(5)

print(versuch)

zwei = [3]

zwei + versuch
# Out:
# [5]
# [3, 5]

# %%
# WIESO in Gottes Namen gibt es hier keine Nummerierungen bei den Aufgaben? xD

# 7 Punkte
# Schreibe eine Funktion die einen positiven Integer erhält.
# Sie gibt den Integer zurück, bei dem dann alle Ziffern
# Vertauscht sind. Führende Nullen werden dabei gestrichen.
#
# 13050 -> 5031
# 0 -> 0
# 1000 -> 1
# 1111 -> 1111

def swap_digets(number):
    first = str(number)
    swap = first[::-1]
    for i in swap:
        if swap[0] == "0":
            swap[0].replace("0", "")
    ergebnis = int(swap)

    return ergebnis


swap_digets(999666777000)
# Out:
# 777666999

# %%
# Spielwiese Aufgabe XXXX

var11 = 5657777
stringss = str(var11)

stringss[::-1]


def swap_digets(number):
    first = str(number)
    swap = first[::-1]
    for i in swap:
        if swap[0] == "0":
            swap[0].replace("0", "")
    ergebnis = int(swap)

    return ergebnis
    
swap_digets(999666000)
# Out:
# 666999

# %%
# 6 Punkte
# Schreibe eine Funktion, die einen String erwartet und
# jeden Kleinbuchstaben groß und jeden Großbuchstaben klein schreibt.
#
# "Aloh" -> "aLOH"
# "" -> ""
# "aaaa" -> "AAAA"
# "Ich bin ein Text" -> "iCH BIN EIN tEXT"
def swap_case(words):
    ...

# %%
from unittest import TestCase
from unittest import main

class TestRemove(TestCase):

    def test_remove_float_and_int_keys_0(self):
        self.assertIsInstance(remove_float_and_int_keys({'h': 1, 4: 2, 2.0: "e"}), dict)

    def test_remove_float_and_int_keys_1(self):
        self.assertDictEqual(remove_float_and_int_keys({'h': 1, 4: 2, 2.0: "e"}), {'h': 1})

    def test_remove_float_and_int_keys_2(self):
        self.assertDictEqual(remove_float_and_int_keys({'h': 1, '4': 2, '2.0': "e"}), {'h': 1, '4': 2, '2.0': "e"})

    def test_remove_float_and_int_keys_3(self):
        self.assertDictEqual(remove_float_and_int_keys({5: 1, 4: 2, 2.0: "e"}), dict())

    def test_remove_float_and_int_keys_4(self):
        self.assertDictEqual(remove_float_and_int_keys(dict()), dict())

    def test_remove_float_and_int_keys_5(self):
        my_dict = {'h': 1, 4: 2, 2.0: "e"}
        _ = remove_float_and_int_keys(my_dict)
        self.assertDictEqual(my_dict, my_dict)

    def test_restort_within_word_0(self):
        self.assertIsInstance(resort_within_word(""), str)

    def test_resort_within_word_1(self):
        result = resort_within_word("Hallo wie geht es dir")
        self.assertEqual(result, "ollaH eiw theg se rid")

    def test_resort_within_word_2(self):
        self.assertEqual(resort_within_word(""), "")

    def test_resort_within_word_3(self):
        self.assertEqual(resort_within_word("abc"), "cba")

    def test_resort_within_word_4(self):
        self.assertEqual(resort_within_word("Aab baA"), "baA Aab")

    def test_resort_within_word_5(self):
        self.assertEqual(resort_within_word("AAA aaa AaA aAa"), "AAA aaa AaA aAa")

    def test_resort_within_word_6(self):
        self.assertEqual(resort_within_word("t t s t"), "t t s t")

    def test_keep_smallest_biggest_0(self):
        self.assertIsInstance(keep_smallest_biggest([]), list)

    def test_keep_smallest_biggest_1(self):
        self.assertListEqual(keep_smallest_biggest([]), [])

    def test_keep_smallest_biggest_2(self):
        self.assertListEqual(keep_smallest_biggest([1, 4, 3, 4, 1, 2]), [1, 4, 4, 1])

    def test_keep_smallest_biggest_3(self):
        self.assertListEqual(keep_smallest_biggest([1]), [1])

    def test_keep_smallest_biggest_4(self):
        self.assertListEqual(keep_smallest_biggest([-3, -4, -5]), [-3, -5])

    def test_keep_smallest_biggest_5(self):
        self.assertListEqual(keep_smallest_biggest(list(range(100_000))), [0, 99_999])

    def test_keep_smallest_biggest_6(self):
        self.assertListEqual(keep_smallest_biggest(list(range(100_000, 0, -1))), [100_000, 1])

    def test_count_letters_0(self):
        self.assertIsInstance(count_letters(""), dict)

    def test_count_letters_1(self):
        result = count_letters("Hallo wie geht es dir?")
        expected = {'?': 1,
                    'H': 1,
                    'a': 1,
                    'd': 1,
                    'e': 3,
                    'g': 1,
                    'h': 1,
                    'i': 2,
                    'l': 2,
                    'o': 1,
                    'r': 1,
                    's': 1,
                    't': 1,
                    'w': 1}
        self.assertEqual(result, expected)

    def test_count_letters_2(self):
        self.assertEqual(count_letters(""), dict())

    def test_count_letters_3(self):
        self.assertEqual(count_letters("   "), dict())

    def test_count_letters_4(self):
        self.assertEqual(count_letters("du da"), {"d": 2, "u": 1, "a": 1})

    def test_count_letters_5(self):
        self.assertEqual(count_letters("a b Aa" * 100), {'a': 200, 'b': 100, 'A': 100})

    def test_count_letters_6(self):
        self.assertEqual(count_letters("12321"), {"1": 2, "2": 2, "3": 1})

    def test_funny_sum_0(self):
        self.assertIsInstance(funny_sum([]), int)

    def test_funny_sum_1(self):
        self.assertEqual(funny_sum([]), 0)

    def test_funny_sum_2(self):
        self.assertEqual(funny_sum([1, 2, 3, 4, 5]), -3)

    def test_funny_sum_3(self):
        self.assertEqual(funny_sum([0, 0, 0]), 0)

    def test_funny_sum_4(self):
        self.assertEqual(funny_sum([-1, -3, -5]), 9)

    def test_funny_sum_5(self):
        self.assertEqual(funny_sum([-1, 1, 3, 4, -4, 8]), 5)

    def test_funny_sum_6(self):
        self.assertEqual(funny_sum(list(range(1001))), 500)

    def test_funny_sum_7(self):
        self.assertEqual(funny_sum(list(range(1000))), -500)

    def test_is_left_bigger_0(self):
        self.assertIsInstance(is_left_bigger([]), tuple)

    def test_is_left_bigger_1(self):
        self.assertTupleEqual(is_left_bigger([]), tuple())

    def test_is_left_bigger_2(self):
        self.assertTupleEqual(is_left_bigger([4]), tuple())

    def test_is_left_bigger_3(self):
        self.assertTupleEqual(is_left_bigger([2, 1]), (True,))

    def test_is_left_bigger_4(self):
        self.assertTupleEqual(is_left_bigger([4, 2, 6, 3, 1, 1]), (True, False, True, True, False))

    def test_is_left_bigger_5(self):
        self.assertTupleEqual(is_left_bigger([4, 2, 6, 3, 1]), (True, False, True, True))

    def test_is_left_bigger_6(self):
        input_list = [4, 2, 6, 3, 1]
        result = is_left_bigger(input_list)
        self.assertEqual(len(result), len(input_list) - 1)

    def test_is_left_bigger_7(self):
        self.assertTupleEqual(is_left_bigger(list(range(100))), (False,) * 99)

    def test_is_left_bigger_8(self):
        self.assertTupleEqual(is_left_bigger(list(range(100, 0, -1))), (True,) * 99)

    def test_swap_digets_0(self):
        self.assertIsInstance(swap_digets(0), int)

    def test_swap_digets_1(self):
        self.assertEqual(swap_digets(13050), 5031)

    def test_swap_digets_2(self):
        self.assertEqual(swap_digets(0), 0)

    def test_swap_digets_3(self):
        self.assertEqual(swap_digets(1234), 4321)

    def test_swap_digets_4(self):
        self.assertEqual(swap_digets(100000), 1)

    def test_swap_digets_5(self):
        self.assertEqual(swap_digets(11111), 11111)

    def test_swap_digets_6(self):
        self.assertEqual(swap_digets(1000011), 1100001)

    def test_swap_case_0(self):
        self.assertIsInstance(swap_case(""), str)

    def test_swap_case_1(self):
        self.assertEqual(swap_case("Aloh"), "aLOH")

    def test_swap_case_2(self):
        self.assertEqual(swap_case(""), "")

    def test_swap_case_3(self):
        self.assertEqual(swap_case("aaaa"), "AAAA")

    def test_swap_case_4(self):
        self.assertEqual(swap_case("Ich bin ein Text"), "iCH BIN EIN tEXT")

    def test_swap_case_5(self):
        text = "Ich bin ein Text  "
        self.assertEqual(swap_case(swap_case(text)), text)

    def test_swap_case_6(self):
        text = "es ist 10 nach 11"
        self.assertEqual(swap_case(text), "ES IST 10 NACH 11")

    def test_add_and_sub_0(self):
        self.assertIsInstance(add_and_sub(1, 1), tuple)

    def test_add_and_sub_1(self):
        r1, r2 = add_and_sub(1, 1)
        self.assertIsInstance(r1, int)
        self.assertIsInstance(r2, int)

    def test_add_and_sub_2(self):
        self.assertEqual(add_and_sub(0, 0), (0, 0))

    def test_add_and_sub_3(self):
        self.assertEqual(add_and_sub(10, 10), (20, 0))

    def test_add_and_sub_4(self):
        self.assertEqual(add_and_sub(12, -10), (2, 22))

    def test_add_and_sub_5(self):
        self.assertEqual(add_and_sub(-22, -3), (-25, -19))

    def test_all_len_0(self):
        self.assertIsInstance(all_len(""), tuple)

    def test_all_len_1(self):
        self.assertTupleEqual(all_len("Hallowiegehts"), (13,))

    def test_all_len_2(self):
        self.assertTupleEqual(all_len("Hallo wie gehts"), (5, 3, 5))

    def test_all_len_3(self):
        self.assertTupleEqual(all_len(""), tuple())

    def test_all_len_4(self):
        self.assertTupleEqual(all_len("   "), tuple())

    def test_all_len_5(self):
        self.assertTupleEqual(all_len("Hallo wer bist  du denn"), (5, 3, 4, 2, 4))

    def test_get_unique_numbers_0(self):
        self.assertIsInstance(get_unique_numbers(""), set)

    def test_get_unique_numbers_1(self):
        self.assertSetEqual(get_unique_numbers("10 10 100 1"), {1, 10, 100})

    def test_get_unique_numbers_2(self):
        self.assertSetEqual(get_unique_numbers("10"), {10})

    def test_get_unique_numbers_3(self):
        self.assertSetEqual(get_unique_numbers("Hier gibt es keine Zahlen"), set())

    def test_get_unique_numbers_4(self):
        self.assertSetEqual(get_unique_numbers("10 ist größer als 8 ist gleich 8"), {8, 10})

    def test_get_unique_numbers_5(self):
        text = "wir sind 100000 und mit 10 wird das 0"
        expected = {100000, 10, 0}
        self.assertEqual(get_unique_numbers(text), expected)

    def test_get_unique_numbers_6(self):
        self.assertEqual(get_unique_numbers("no numbers here"), set())

    def test_change_type_0(self):
        self.assertIsInstance(change_type(list()), tuple)

    def test_change_type_1(self):
        self.assertIsInstance(change_type(set()), list)

    def test_change_type_2(self):
        self.assertIsInstance(change_type(tuple()), set)

    def test_change_type_3(self):
        self.assertTupleEqual(change_type(list()), tuple())

    def test_change_type_4(self):
        self.assertTupleEqual(change_type([1, 2, 3]), (1, 2, 3))

    def test_change_type_5(self):
        self.assertListEqual(change_type(set()), list())

    def test_change_type_6(self):
        self.assertListEqual(change_type({1, 2, 3, 2, 1}), [1, 3])

    def test_change_type_7(self):
        self.assertListEqual(change_type({1}), [1, 1])

    def test_change_type_8(self):
        self.assertSetEqual(change_type(tuple()), set())

    def test_change_type_9(self):
        self.assertSetEqual(change_type((1, 2, 3, 2, 1)), {1, 2, 3})

    def test_apply_operation_0(self):
        def add(a, b):
            return a + b

        self.assertIsInstance(apply_operation([], add), list)

    def test_apply_operation_1(self):
        def add(a, b):
            return a + b

        self.assertListEqual(apply_operation([(1, 3), (4.5, 5.5)], add), [4, 10.0])

    def test_apply_operation_2(self):
        def add(a, b):
            return a + b

        self.assertListEqual(apply_operation([("du", "da")], add), ["duda"])

    def test_apply_operation_3(self):
        self.assertListEqual(apply_operation([(1, 3), (4.5, 5.5)], max), [3, 5.5])

    def test_apply_operation_4(self):
        self.assertListEqual(apply_operation([], max), [])

    def test_apply_operation_5(self):
        self.assertListEqual(apply_operation([("A", "B"), ("C", "D")], max), ["B", "D"])

    def test_deep_positive_check_0(self):
        self.assertIsInstance(deep_positive_check([[1]], True), list)

    def test_deep_positive_check_1(self):
        self.assertListEqual(deep_positive_check([[1]]), [[True]])

    def test_deep_positive_check_2(self):
        self.assertListEqual(deep_positive_check([[1, 2], [0, -1], [-1, 0, 1]]),
                             [[True, True], [True, False], [False, True, True]])

    def test_deep_positive_check_3(self):
        self.assertListEqual(deep_positive_check([[1, 2], [0, -1], [-1, 0, 1]], False),
                             [[True, True], [False, False], [False, False, True]])

    def test_deep_positive_check_4(self):
        self.assertListEqual(deep_positive_check([[1, -1, 0]]), [[True, False, True]])

    def test_deep_positive_check_5(self):
        self.assertListEqual(deep_positive_check([[1], [-1], [0]]), [[True], [False], [True]])

    def test_deep_positive_check_6(self):
        self.assertTupleEqual(deep_positive_check.__defaults__, (True,))
        
main(argv=[''], verbosity=1, exit=False)
# Out:
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE.E.......FFFFFFF.......
# ======================================================================
# ERROR: test_add_and_sub_0 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 203, in test_add_and_sub_0
#     self.assertIsInstance(add_and_sub(1, 1), tuple)
# NameError: name 'add_and_sub' is not defined
#
# ======================================================================
# ERROR: test_add_and_sub_1 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 206, in test_add_and_sub_1
#     r1, r2 = add_and_sub(1, 1)
# NameError: name 'add_and_sub' is not defined
#
# ======================================================================
# ERROR: test_add_and_sub_2 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 211, in test_add_and_sub_2
#     self.assertEqual(add_and_sub(0, 0), (0, 0))
# NameError: name 'add_and_sub' is not defined
#
# ======================================================================
# ERROR: test_add_and_sub_3 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 214, in test_add_and_sub_3
#     self.assertEqual(add_and_sub(10, 10), (20, 0))
# NameError: name 'add_and_sub' is not defined
#
# ======================================================================
# ERROR: test_add_and_sub_4 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 217, in test_add_and_sub_4
#     self.assertEqual(add_and_sub(12, -10), (2, 22))
# NameError: name 'add_and_sub' is not defined
#
# ======================================================================
# ERROR: test_add_and_sub_5 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 220, in test_add_and_sub_5
#     self.assertEqual(add_and_sub(-22, -3), (-25, -19))
# NameError: name 'add_and_sub' is not defined
#
# ======================================================================
# ERROR: test_all_len_0 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 223, in test_all_len_0
#     self.assertIsInstance(all_len(""), tuple)
# NameError: name 'all_len' is not defined
#
# ======================================================================
# ERROR: test_all_len_1 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 226, in test_all_len_1
#     self.assertTupleEqual(all_len("Hallowiegehts"), (13,))
# NameError: name 'all_len' is not defined
#
# ======================================================================
# ERROR: test_all_len_2 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 229, in test_all_len_2
#     self.assertTupleEqual(all_len("Hallo wie gehts"), (5, 3, 5))
# NameError: name 'all_len' is not defined
#
# ======================================================================
# ERROR: test_all_len_3 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 232, in test_all_len_3
#     self.assertTupleEqual(all_len(""), tuple())
# NameError: name 'all_len' is not defined
#
# ======================================================================
# ERROR: test_all_len_4 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 235, in test_all_len_4
#     self.assertTupleEqual(all_len("   "), tuple())
# NameError: name 'all_len' is not defined
#
# ======================================================================
# ERROR: test_all_len_5 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 238, in test_all_len_5
#     self.assertTupleEqual(all_len("Hallo wer bist  du denn"), (5, 3, 4, 2, 4))
# NameError: name 'all_len' is not defined
#
# ======================================================================
# ERROR: test_apply_operation_0 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 297, in test_apply_operation_0
#     self.assertIsInstance(apply_operation([], add), list)
# NameError: name 'apply_operation' is not defined
#
# ======================================================================
# ERROR: test_apply_operation_1 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 303, in test_apply_operation_1
#     self.assertListEqual(apply_operation([(1, 3), (4.5, 5.5)], add), [4, 10.0])
# NameError: name 'apply_operation' is not defined
#
# ======================================================================
# ERROR: test_apply_operation_2 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 309, in test_apply_operation_2
#     self.assertListEqual(apply_operation([("du", "da")], add), ["duda"])
# NameError: name 'apply_operation' is not defined
#
# ======================================================================
# ERROR: test_apply_operation_3 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 312, in test_apply_operation_3
#     self.assertListEqual(apply_operation([(1, 3), (4.5, 5.5)], max), [3, 5.5])
# NameError: name 'apply_operation' is not defined
#
# ======================================================================
# ERROR: test_apply_operation_4 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 315, in test_apply_operation_4
#     self.assertListEqual(apply_operation([], max), [])
# NameError: name 'apply_operation' is not defined
#
# ======================================================================
# ERROR: test_apply_operation_5 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 318, in test_apply_operation_5
#     self.assertListEqual(apply_operation([("A", "B"), ("C", "D")], max), ["B", "D"])
# NameError: name 'apply_operation' is not defined
#
# ======================================================================
# ERROR: test_change_type_0 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 264, in test_change_type_0
#     self.assertIsInstance(change_type(list()), tuple)
# NameError: name 'change_type' is not defined
# ======================================================================
# ERROR: test_change_type_1 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 267, in test_change_type_1
#     self.assertIsInstance(change_type(set()), list)
# NameError: name 'change_type' is not defined
#
# ======================================================================
# ERROR: test_change_type_2 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 270, in test_change_type_2
#     self.assertIsInstance(change_type(tuple()), set)
# NameError: name 'change_type' is not defined
#
# ======================================================================
# ERROR: test_change_type_3 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 273, in test_change_type_3
#     self.assertTupleEqual(change_type(list()), tuple())
# NameError: name 'change_type' is not defined
#
# ======================================================================
# ERROR: test_change_type_4 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 276, in test_change_type_4
#     self.assertTupleEqual(change_type([1, 2, 3]), (1, 2, 3))
# NameError: name 'change_type' is not defined
#
# ======================================================================
# ERROR: test_change_type_5 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 279, in test_change_type_5
#     self.assertListEqual(change_type(set()), list())
# NameError: name 'change_type' is not defined
#
# ======================================================================
# ERROR: test_change_type_6 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 282, in test_change_type_6
#     self.assertListEqual(change_type({1, 2, 3, 2, 1}), [1, 3])
# NameError: name 'change_type' is not defined
#
# ======================================================================
# ERROR: test_change_type_7 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 285, in test_change_type_7
#     self.assertListEqual(change_type({1}), [1, 1])
# NameError: name 'change_type' is not defined
#
# ======================================================================
# ERROR: test_change_type_8 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 288, in test_change_type_8
#     self.assertSetEqual(change_type(tuple()), set())
# NameError: name 'change_type' is not defined
#
# ======================================================================
# ERROR: test_change_type_9 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 291, in test_change_type_9
#     self.assertSetEqual(change_type((1, 2, 3, 2, 1)), {1, 2, 3})
# NameError: name 'change_type' is not defined
#
# ======================================================================
# ERROR: test_count_letters_0 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 70, in test_count_letters_0
#     self.assertIsInstance(count_letters(""), dict)
# NameError: name 'count_letters' is not defined
#
# ======================================================================
# ERROR: test_count_letters_1 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 73, in test_count_letters_1
#     result = count_letters("Hallo wie geht es dir?")
# NameError: name 'count_letters' is not defined
#
# ======================================================================
# ERROR: test_count_letters_2 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 91, in test_count_letters_2
#     self.assertEqual(count_letters(""), dict())
# NameError: name 'count_letters' is not defined
#
# ======================================================================
# ERROR: test_count_letters_3 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 94, in test_count_letters_3
#     self.assertEqual(count_letters("   "), dict())
# NameError: name 'count_letters' is not defined
#
# ======================================================================
# ERROR: test_count_letters_4 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 97, in test_count_letters_4
#     self.assertEqual(count_letters("du da"), {"d": 2, "u": 1, "a": 1})
# NameError: name 'count_letters' is not defined
#
# ======================================================================
# ERROR: test_count_letters_5 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 100, in test_count_letters_5
#     self.assertEqual(count_letters("a b Aa" * 100), {'a': 200, 'b': 100, 'A': 100})
# NameError: name 'count_letters' is not defined
#
# ======================================================================
# ERROR: test_count_letters_6 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 103, in test_count_letters_6
#     self.assertEqual(count_letters("12321"), {"1": 2, "2": 2, "3": 1})
# NameError: name 'count_letters' is not defined
#
# ======================================================================
# ERROR: test_deep_positive_check_0 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 321, in test_deep_positive_check_0
#     self.assertIsInstance(deep_positive_check([[1]], True), list)
# NameError: name 'deep_positive_check' is not defined
#
# ======================================================================
# ERROR: test_deep_positive_check_1 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 324, in test_deep_positive_check_1
#     self.assertListEqual(deep_positive_check([[1]]), [[True]])
# NameError: name 'deep_positive_check' is not defined
#
# ======================================================================
# ERROR: test_deep_positive_check_2 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 327, in test_deep_positive_check_2
#     self.assertListEqual(deep_positive_check([[1, 2], [0, -1], [-1, 0, 1]]),
# NameError: name 'deep_positive_check' is not defined
# ======================================================================
# ERROR: test_deep_positive_check_3 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 331, in test_deep_positive_check_3
#     self.assertListEqual(deep_positive_check([[1, 2], [0, -1], [-1, 0, 1]], False),
# NameError: name 'deep_positive_check' is not defined
#
# ======================================================================
# ERROR: test_deep_positive_check_4 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 335, in test_deep_positive_check_4
#     self.assertListEqual(deep_positive_check([[1, -1, 0]]), [[True, False, True]])
# NameError: name 'deep_positive_check' is not defined
#
# ======================================================================
# ERROR: test_deep_positive_check_5 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 338, in test_deep_positive_check_5
#     self.assertListEqual(deep_positive_check([[1], [-1], [0]]), [[True], [False], [True]])
# NameError: name 'deep_positive_check' is not defined
#
# ======================================================================
# ERROR: test_deep_positive_check_6 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 341, in test_deep_positive_check_6
#     self.assertTupleEqual(deep_positive_check.__defaults__, (True,))
# NameError: name 'deep_positive_check' is not defined
#
# ======================================================================
# ERROR: test_funny_sum_0 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 106, in test_funny_sum_0
#     self.assertIsInstance(funny_sum([]), int)
# NameError: name 'funny_sum' is not defined
#
# ======================================================================
# ERROR: test_funny_sum_1 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 109, in test_funny_sum_1
#     self.assertEqual(funny_sum([]), 0)
# NameError: name 'funny_sum' is not defined
#
# ======================================================================
# ERROR: test_funny_sum_2 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 112, in test_funny_sum_2
#     self.assertEqual(funny_sum([1, 2, 3, 4, 5]), -3)
# NameError: name 'funny_sum' is not defined
#
# ======================================================================
# ERROR: test_funny_sum_3 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 115, in test_funny_sum_3
#     self.assertEqual(funny_sum([0, 0, 0]), 0)
# NameError: name 'funny_sum' is not defined
#
# ======================================================================
# ERROR: test_funny_sum_4 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 118, in test_funny_sum_4
#     self.assertEqual(funny_sum([-1, -3, -5]), 9)
# NameError: name 'funny_sum' is not defined
#
# ======================================================================
# ERROR: test_funny_sum_5 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 121, in test_funny_sum_5
#     self.assertEqual(funny_sum([-1, 1, 3, 4, -4, 8]), 5)
# NameError: name 'funny_sum' is not defined
#
# ======================================================================
# ERROR: test_funny_sum_6 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 124, in test_funny_sum_6
#     self.assertEqual(funny_sum(list(range(1001))), 500)
# NameError: name 'funny_sum' is not defined
#
# ======================================================================
# ERROR: test_funny_sum_7 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 127, in test_funny_sum_7
#     self.assertEqual(funny_sum(list(range(1000))), -500)
# NameError: name 'funny_sum' is not defined
#
# ======================================================================
# ERROR: test_get_unique_numbers_0 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 241, in test_get_unique_numbers_0
#     self.assertIsInstance(get_unique_numbers(""), set)
# NameError: name 'get_unique_numbers' is not defined
#
# ======================================================================
# ERROR: test_get_unique_numbers_1 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 244, in test_get_unique_numbers_1
#     self.assertSetEqual(get_unique_numbers("10 10 100 1"), {1, 10, 100})
# NameError: name 'get_unique_numbers' is not defined
#
# ======================================================================
# ERROR: test_get_unique_numbers_2 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 247, in test_get_unique_numbers_2
#     self.assertSetEqual(get_unique_numbers("10"), {10})
# NameError: name 'get_unique_numbers' is not defined
#
# ======================================================================
# ERROR: test_get_unique_numbers_3 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 250, in test_get_unique_numbers_3
#     self.assertSetEqual(get_unique_numbers("Hier gibt es keine Zahlen"), set())
# NameError: name 'get_unique_numbers' is not defined
#
# ======================================================================
# ERROR: test_get_unique_numbers_4 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 253, in test_get_unique_numbers_4
#     self.assertSetEqual(get_unique_numbers("10 ist größer als 8 ist gleich 8"), {8, 10})
# NameError: name 'get_unique_numbers' is not defined
#
# ======================================================================
# ERROR: test_get_unique_numbers_5 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 258, in test_get_unique_numbers_5
#     self.assertEqual(get_unique_numbers(text), expected)
# NameError: name 'get_unique_numbers' is not defined
#
# ======================================================================
# ERROR: test_get_unique_numbers_6 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 261, in test_get_unique_numbers_6
#     self.assertEqual(get_unique_numbers("no numbers here"), set())
# NameError: name 'get_unique_numbers' is not defined
# ======================================================================
# ERROR: test_is_left_bigger_0 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 130, in test_is_left_bigger_0
#     self.assertIsInstance(is_left_bigger([]), tuple)
# NameError: name 'is_left_bigger' is not defined
#
# ======================================================================
# ERROR: test_is_left_bigger_1 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 133, in test_is_left_bigger_1
#     self.assertTupleEqual(is_left_bigger([]), tuple())
# NameError: name 'is_left_bigger' is not defined
#
# ======================================================================
# ERROR: test_is_left_bigger_2 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 136, in test_is_left_bigger_2
#     self.assertTupleEqual(is_left_bigger([4]), tuple())
# NameError: name 'is_left_bigger' is not defined
#
# ======================================================================
# ERROR: test_is_left_bigger_3 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 139, in test_is_left_bigger_3
#     self.assertTupleEqual(is_left_bigger([2, 1]), (True,))
# NameError: name 'is_left_bigger' is not defined
#
# ======================================================================
# ERROR: test_is_left_bigger_4 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 142, in test_is_left_bigger_4
#     self.assertTupleEqual(is_left_bigger([4, 2, 6, 3, 1, 1]), (True, False, True, True, False))
# NameError: name 'is_left_bigger' is not defined
#
# ======================================================================
# ERROR: test_is_left_bigger_5 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 145, in test_is_left_bigger_5
#     self.assertTupleEqual(is_left_bigger([4, 2, 6, 3, 1]), (True, False, True, True))
# NameError: name 'is_left_bigger' is not defined
#
# ======================================================================
# ERROR: test_is_left_bigger_6 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 149, in test_is_left_bigger_6
#     result = is_left_bigger(input_list)
# NameError: name 'is_left_bigger' is not defined
#
# ======================================================================
# ERROR: test_is_left_bigger_7 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 153, in test_is_left_bigger_7
#     self.assertTupleEqual(is_left_bigger(list(range(100))), (False,) * 99)
# NameError: name 'is_left_bigger' is not defined
#
# ======================================================================
# ERROR: test_is_left_bigger_8 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 156, in test_is_left_bigger_8
#     self.assertTupleEqual(is_left_bigger(list(range(100, 0, -1))), (True,) * 99)
# NameError: name 'is_left_bigger' is not defined
#
# ======================================================================
# ERROR: test_keep_smallest_biggest_0 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 49, in test_keep_smallest_biggest_0
#     self.assertIsInstance(keep_smallest_biggest([]), list)
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\991687870.py", line 13, in keep_smallest_biggest
#     klein = my_list[0]
# IndexError: list index out of range
#
# ======================================================================
# ERROR: test_keep_smallest_biggest_1 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 52, in test_keep_smallest_biggest_1
#     self.assertListEqual(keep_smallest_biggest([]), [])
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\991687870.py", line 13, in keep_smallest_biggest
#     klein = my_list[0]
# IndexError: list index out of range
#
# ======================================================================
# ERROR: test_keep_smallest_biggest_2 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 55, in test_keep_smallest_biggest_2
#     self.assertListEqual(keep_smallest_biggest([1, 4, 3, 4, 1, 2]), [1, 4, 4, 1])
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\991687870.py", line 16, in keep_smallest_biggest
#     if i >= max(groß):
# TypeError: 'int' object is not iterable
#
# ======================================================================
# ERROR: test_keep_smallest_biggest_3 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 58, in test_keep_smallest_biggest_3
#     self.assertListEqual(keep_smallest_biggest([1]), [1])
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\991687870.py", line 16, in keep_smallest_biggest
#     if i >= max(groß):
# TypeError: 'int' object is not iterable
#
# ======================================================================
# ERROR: test_keep_smallest_biggest_4 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 61, in test_keep_smallest_biggest_4
#     self.assertListEqual(keep_smallest_biggest([-3, -4, -5]), [-3, -5])
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\991687870.py", line 16, in keep_smallest_biggest
#     if i >= max(groß):
# TypeError: 'int' object is not iterable
#
# ======================================================================
# ERROR: test_keep_smallest_biggest_5 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 64, in test_keep_smallest_biggest_5
#     self.assertListEqual(keep_smallest_biggest(list(range(100_000))), [0, 99_999])
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\991687870.py", line 16, in keep_smallest_biggest
#     if i >= max(groß):
# TypeError: 'int' object is not iterable
#
# ======================================================================
# ERROR: test_keep_smallest_biggest_6 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 67, in test_keep_smallest_biggest_6
#     self.assertListEqual(keep_smallest_biggest(list(range(100_000, 0, -1))), [100_000, 1])
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\991687870.py", line 16, in keep_smallest_biggest
#     if i >= max(groß):
# TypeError: 'int' object is not iterable
# ======================================================================
# ERROR: test_remove_float_and_int_keys_0 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 7, in test_remove_float_and_int_keys_0
#     self.assertIsInstance(remove_float_and_int_keys({'h': 1, 4: 2, 2.0: "e"}), dict)
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\3285273485.py", line 15, in remove_float_and_int_keys
#     dict_neu.pop(i)
# KeyError: 'h'
#
# ======================================================================
# ERROR: test_remove_float_and_int_keys_1 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 10, in test_remove_float_and_int_keys_1
#     self.assertDictEqual(remove_float_and_int_keys({'h': 1, 4: 2, 2.0: "e"}), {'h': 1})
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\3285273485.py", line 15, in remove_float_and_int_keys
#     dict_neu.pop(i)
# KeyError: 'h'
#
# ======================================================================
# ERROR: test_remove_float_and_int_keys_2 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 13, in test_remove_float_and_int_keys_2
#     self.assertDictEqual(remove_float_and_int_keys({'h': 1, '4': 2, '2.0': "e"}), {'h': 1, '4': 2, '2.0': "e"})
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\3285273485.py", line 15, in remove_float_and_int_keys
#     dict_neu.pop(i)
# KeyError: 'h'
#
# ======================================================================
# ERROR: test_remove_float_and_int_keys_3 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 16, in test_remove_float_and_int_keys_3
#     self.assertDictEqual(remove_float_and_int_keys({5: 1, 4: 2, 2.0: "e"}), dict())
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\3285273485.py", line 14, in remove_float_and_int_keys
#     if type(i[0]) != int or type(i[0]) != float:
# TypeError: 'int' object is not subscriptable
#
# ======================================================================
# ERROR: test_remove_float_and_int_keys_5 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 23, in test_remove_float_and_int_keys_5
#     _ = remove_float_and_int_keys(my_dict)
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\3285273485.py", line 15, in remove_float_and_int_keys
#     dict_neu.pop(i)
# KeyError: 'h'
#
# ======================================================================
# FAIL: test_swap_case_0 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 180, in test_swap_case_0
#     self.assertIsInstance(swap_case(""), str)
# AssertionError: None is not an instance of <class 'str'>
#
# ======================================================================
# FAIL: test_swap_case_1 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 183, in test_swap_case_1
#     self.assertEqual(swap_case("Aloh"), "aLOH")
# AssertionError: None != 'aLOH'
#
# ======================================================================
# FAIL: test_swap_case_2 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 186, in test_swap_case_2
#     self.assertEqual(swap_case(""), "")
# AssertionError: None != ''
#
# ======================================================================
# FAIL: test_swap_case_3 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 189, in test_swap_case_3
#     self.assertEqual(swap_case("aaaa"), "AAAA")
# AssertionError: None != 'AAAA'
#
# ======================================================================
# FAIL: test_swap_case_4 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 192, in test_swap_case_4
#     self.assertEqual(swap_case("Ich bin ein Text"), "iCH BIN EIN tEXT")
# AssertionError: None != 'iCH BIN EIN tEXT'
#
# ======================================================================
# FAIL: test_swap_case_5 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 196, in test_swap_case_5
#     self.assertEqual(swap_case(swap_case(text)), text)
# AssertionError: None != 'Ich bin ein Text  '
#
# ======================================================================
# FAIL: test_swap_case_6 (__main__.TestRemove)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Vikto\AppData\Local\Temp\ipykernel_12092\1331378512.py", line 200, in test_swap_case_6
#     self.assertEqual(swap_case(text), "ES IST 10 NACH 11")
# AssertionError: None != 'ES IST 10 NACH 11'
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.079s
#
# FAILED (failures=7, errors=78)
